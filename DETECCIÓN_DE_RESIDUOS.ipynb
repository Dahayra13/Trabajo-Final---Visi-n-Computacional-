# %%
# !nvidia-smi
# Out:
# Tue Jul  2 02:50:37 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA A100-SXM4-40GB          Off | 00000000:00:04.0 Off |                    0 |
# | N/A   32C    P0              46W / 400W |      2MiB / 40960MiB |      0%      Default |
# |                                         |                      |             Disabled |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %%
# !git clone https://github.com/SkalskiP/yolov9.git
# %cd yolov9
# !pip install -r requirements.txt -q
# Out:
# Cloning into 'yolov9'...
# remote: Enumerating objects: 325, done.
# remote: Counting objects: 100% (218/218), done.
# remote: Compressing objects: 100% (62/62), done.
# remote: Total 325 (delta 159), reused 156 (delta 156), pack-reused 107
# Receiving objects: 100% (325/325), 2.23 MiB | 45.77 MiB/s, done.
# Resolving deltas: 100% (165/165), done.
# /content/yolov9
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 5.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 8.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 44.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 61.5 MB/s eta 0:00:00

# %%
# !pip install -q roboflow
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 3.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 11.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 7.5 MB/s eta 0:00:00

# %%
# !wget -P {HOME}/weights -q https://github.com/WongKinYiu/yolov9/releases/download/v0.1/yolov9-c.pt
# !wget -P {HOME}/weights -q https://github.com/WongKinYiu/yolov9/releases/download/v0.1/yolov9-e.pt
# !wget -P {HOME}/weights -q https://github.com/WongKinYiu/yolov9/releases/download/v0.1/gelan-c.pt
# !wget -P {HOME}/weights -q https://github.com/WongKinYiu/yolov9/releases/download/v0.1/gelan-e.pt

# %%
# !ls -la {HOME}/weights
# Out:
# total 402440
# drwxr-xr-x 2 root root      4096 Jul  2 02:52 .
# drwxr-xr-x 1 root root      4096 Jul  2 02:52 ..
# -rw-r--r-- 1 root root  51508261 Feb 18 12:36 gelan-c.pt
# -rw-r--r-- 1 root root 117203713 Feb 18 12:36 gelan-e.pt
# -rw-r--r-- 1 root root 103153312 Feb 18 12:36 yolov9-c.pt
# -rw-r--r-- 1 root root 140217688 Feb 18 12:36 yolov9-e.pt

# %%
# !wget -P {HOME}/data -q https://media.roboflow.com/notebooks/examples/dog.jpeg

# %%
SOURCE_IMAGE_PATH = f"{HOME}/Basura.jpeg"

# %%
# !python detect.py --weights {HOME}/weights/gelan-c.pt --conf 0.1 --source {HOME}/data/Basura.jpeg --device 0
# Out:
# detect: weights=['/content/weights/gelan-c.pt'], source=/content/data/Basura.jpeg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=0, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 1e33dbb Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
#
# Fusing layers...
# Model summary: 467 layers, 25472640 parameters, 0 gradients, 102.8 GFLOPs
# image 1/1 /content/data/Basura.jpeg: 640x640 1 suitcase, 5 bottles, 17.0ms
# Speed: 0.6ms pre-process, 17.0ms inference, 793.4ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp

# %%
from IPython.display import Image

Image(filename=f"{HOME}/yolov9/runs/detect/exp/Basura.jpeg", width=600)

# %%
# !python detect.py --weights {HOME}/weights/yolov9-e.pt --conf 0.1 --source {HOME}/data/Basura.jpeg --device 0
# Out:
# detect: weights=['/content/weights/yolov9-e.pt'], source=/content/data/Basura.jpeg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=0, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 1e33dbb Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
#
# Fusing layers...
# Model summary: 1119 layers, 69470144 parameters, 0 gradients, 244.0 GFLOPs
# image 1/1 /content/data/Basura.jpeg: 640x640 1 handbag, 1 suitcase, 5 bottles, 38.9ms
# Speed: 0.6ms pre-process, 38.9ms inference, 547.1ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp2

# %%
from IPython.display import Image

Image(filename=f"{HOME}/yolov9/runs/detect/exp2/Basura.jpeg", width=600)

# %%
# %cd {HOME}/yolov9
# Out:
# /content/yolov9

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="owlqaOdSGhLb078zPaIw")
project = rf.workspace("trash-sorter").project("synthetic-trashes")
version = project.version(2)
dataset = version.download("yolov9")
# Out:
# Requirement already satisfied: roboflow in /usr/local/lib/python3.10/dist-packages (1.1.33)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from roboflow) (2024.6.2)
# Requirement already satisfied: chardet==4.0.0 in /usr/local/lib/python3.10/dist-packages (from roboflow) (4.0.0)
# Requirement already satisfied: idna==3.7 in /usr/local/lib/python3.10/dist-packages (from roboflow) (3.7)
# Requirement already satisfied: cycler in /usr/local/lib/python3.10/dist-packages (from roboflow) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.4.5)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from roboflow) (3.7.1)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.25.2)
# Requirement already satisfied: opencv-python-headless==4.10.0.84 in /usr/local/lib/python3.10/dist-packages (from roboflow) (4.10.0.84)
# Requirement already satisfied: Pillow>=7.1.2 in /usr/local/lib/python3.10/dist-packages (from roboflow) (9.4.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.8.2)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.0.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.31.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.16.0)
# Requirement already satisfied: urllib3>=1.26.6 in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.0.7)
# Requirement already satisfied: tqdm>=4.41.0 in /usr/local/lib/python3.10/dist-packages (from roboflow) (4.66.4)
# Requirement already satisfied: PyYAML>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from roboflow) (6.0.1)
# Requirement already satisfied: requests-toolbelt in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.0.0)
# Requirement already satisfied: python-magic in /usr/local/lib/python3.10/dist-packages (from roboflow) (0.4.27)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (1.2.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (4.53.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (3.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->roboflow) (3.3.2)
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in Synthetic-trashes-2 to yolov9:: 100%|██████████| 44546/44546 [00:03<00:00, 12109.61it/s]
# Extracting Dataset Version Zip to Synthetic-trashes-2 in yolov9:: 100%|██████████| 1618/1618 [00:00<00:00, 5114.40it/s]

# %%
# %cd {HOME}/yolov9

# !python train.py \
--batch 16 --epochs 30 --img 600 --device 0 --min-items 0 --close-mosaic 15 \
--data {dataset.location}/data.yaml \
--weights {HOME}/weights/gelan-c.pt \
--cfg models/detect/gelan-c.yaml \
--hyp hyp.scratch-high.yaml
# Out:
# /content/yolov9
# 2024-07-02 02:54:52.939719: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-07-02 02:54:52.991276: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-02 02:54:52.991322: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-02 02:54:52.992907: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-07-02 02:54:53.000989: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-07-02 02:54:54.218419: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# train: weights=/content/weights/gelan-c.pt, cfg=models/detect/gelan-c.yaml, data=/content/yolov9/Synthetic-trashes-2/data.yaml, hyp=hyp.scratch-high.yaml, epochs=30, batch_size=16, imgsz=600, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=0, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, flat_cos_lr=False, fixed_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, min_items=0, close_mosaic=15, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# YOLOv5 🚀 1e33dbb Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, cls_pw=1.0, dfl=1.5, obj_pw=1.0, iou_t=0.2, anchor_t=5.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.9, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.15, copy_paste=0.3
# ClearML: run 'pip install clearml' to automatically track, visualize and remotely train YOLO 🚀 in ClearML
# Comet: run 'pip install comet_ml' to automatically track and visualize YOLO 🚀 runs in Comet
# TensorBoard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# Downloading https://ultralytics.com/assets/Arial.ttf to /root/.config/Ultralytics/Arial.ttf...
# 100% 755k/755k [00:00<00:00, 15.8MB/s]
# Overriding model.yaml nc=80 with nc=8
#
#                  from  n    params  module                                  arguments
#   0                -1  1      1856  models.common.Conv                      [3, 64, 3, 2]
#   1                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   2                -1  1    212864  models.common.RepNCSPELAN4              [128, 256, 128, 64, 1]
#   3                -1  1    164352  models.common.ADown                     [256, 256]
#   4                -1  1    847616  models.common.RepNCSPELAN4              [256, 512, 256, 128, 1]
#   5                -1  1    656384  models.common.ADown                     [512, 512]
#   6                -1  1   2857472  models.common.RepNCSPELAN4              [512, 512, 512, 256, 1]
#   7                -1  1    656384  models.common.ADown                     [512, 512]
#   8                -1  1   2857472  models.common.RepNCSPELAN4              [512, 512, 512, 256, 1]
#   9                -1  1    656896  models.common.SPPELAN                   [512, 512, 256]
#  10                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  11           [-1, 6]  1         0  models.common.Concat                    [1]
#  12                -1  1   3119616  models.common.RepNCSPELAN4              [1024, 512, 512, 256, 1]
#  13                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  14           [-1, 4]  1         0  models.common.Concat                    [1]
#  15                -1  1    912640  models.common.RepNCSPELAN4              [1024, 256, 256, 128, 1]
#  16                -1  1    164352  models.common.ADown                     [256, 256]
#  17          [-1, 12]  1         0  models.common.Concat                    [1]
#  18                -1  1   2988544  models.common.RepNCSPELAN4              [768, 512, 512, 256, 1]
#  19                -1  1    656384  models.common.ADown                     [512, 512]
#  20           [-1, 9]  1         0  models.common.Concat                    [1]
#  21                -1  1   3119616  models.common.RepNCSPELAN4              [1024, 512, 512, 256, 1]
#  22      [15, 18, 21]  1   5496808  models.yolo.DDetect                     [8, [256, 512, 512]]
# gelan-c summary: 621 layers, 25443240 parameters, 25443224 gradients, 103.2 GFLOPs
#
# Transferred 931/937 items from /content/weights/gelan-c.pt
# AMP: checks passed ✅
# WARNING ⚠️ --img-size 600 must be multiple of max stride 32, updating to 608
# optimizer: SGD(lr=0.01) with parameter groups 154 weight(decay=0.0), 161 weight(decay=0.0005), 160 bias
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# train: Scanning /content/yolov9/Synthetic-trashes-2/train/labels... 563 images, 0 backgrounds, 0 corrupt: 100% 563/563 [00:00<00:00, 4104.86it/s]
# train: New cache created: /content/yolov9/Synthetic-trashes-2/train/labels.cache
# val: Scanning /content/yolov9/Synthetic-trashes-2/valid/labels... 150 images, 0 backgrounds, 0 corrupt: 100% 150/150 [00:00<00:00, 2731.35it/s]
# val: New cache created: /content/yolov9/Synthetic-trashes-2/valid/labels.cache
# Plotting labels to runs/train/exp/labels.jpg...
# Image sizes 608 train, 608 val
# Using 8 dataloader workers
# Logging results to runs/train/exp
# Starting training for 30 epochs...
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        0/29      10.4G      1.198      4.461      1.333        538        608:   0% 0/36 [00:04<?, ?it/s]WARNING ⚠️ TensorBoard graph visualization failure Sizes of tensors must match except in dimension 1. Expected size 36 but got size 37 for tensor number 1 in the list.
#        0/29      19.6G     0.9542      2.832      1.168        107        608: 100% 36/36 [00:24<00:00,  1.49it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:03<00:00,  1.55it/s]
#                    all        150       2589      0.592       0.33      0.286      0.243
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/29      26.3G     0.8313      1.453      1.049        184        608: 100% 36/36 [00:09<00:00,  3.79it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:01<00:00,  2.91it/s]
#                    all        150       2589       0.61      0.502      0.512      0.435
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/29      26.3G     0.9007      1.225      1.036        182        608: 100% 36/36 [00:09<00:00,  3.81it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:01<00:00,  2.98it/s]
#                    all        150       2589      0.648      0.508      0.544      0.461
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/29      26.3G     0.8908      1.174      1.038        111        608: 100% 36/36 [00:09<00:00,  3.89it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:01<00:00,  3.12it/s]
#                    all        150       2589      0.742      0.581      0.654      0.561
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/29      26.3G     0.8545      1.012      1.029        100        608: 100% 36/36 [00:09<00:00,  3.88it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:01<00:00,  3.19it/s]
#                    all        150       2589      0.757      0.603       0.67      0.587
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/29      26.3G     0.8489     0.9699      1.032        115        608: 100% 36/36 [00:09<00:00,  3.76it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:01<00:00,  3.13it/s]
#                    all        150       2589      0.759      0.541      0.633      0.537
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/29      26.3G     0.8759     0.9671      1.041        124        608: 100% 36/36 [00:10<00:00,  3.58it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:01<00:00,  3.18it/s]
#                    all        150       2589       0.74       0.61      0.689      0.596
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/29      26.3G     0.8278     0.8481      1.012        210        608: 100% 36/36 [00:09<00:00,  3.80it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:01<00:00,  3.16it/s]
#                    all        150       2589      0.809      0.673      0.751      0.655
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/29      26.3G     0.8092     0.8299      1.018         95        608: 100% 36/36 [00:09<00:00,  3.68it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:01<00:00,  3.17it/s]
#                    all        150       2589      0.841      0.686      0.762      0.651
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/29      26.3G     0.7976     0.8141      1.011        176        608: 100% 36/36 [00:09<00:00,  3.86it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:01<00:00,  3.09it/s]
#                    all        150       2589      0.866      0.652      0.748      0.646
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/29      28.1G      0.792      0.823      1.013        188        608: 100% 36/36 [00:09<00:00,  3.77it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:01<00:00,  3.16it/s]
#                    all        150       2589      0.804      0.657      0.745      0.648
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/29      28.1G     0.7602     0.7826     0.9951        105        608: 100% 36/36 [00:09<00:00,  3.68it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:01<00:00,  3.19it/s]
#                    all        150       2589      0.863      0.684      0.772      0.679
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/29      28.1G     0.7536     0.7584     0.9925         91        608: 100% 36/36 [00:09<00:00,  3.80it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:01<00:00,  3.06it/s]
#                    all        150       2589      0.874      0.659       0.76      0.677
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/29      28.1G     0.7502     0.7709     0.9989        114        608: 100% 36/36 [00:09<00:00,  3.89it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:01<00:00,  3.11it/s]
#                    all        150       2589       0.83      0.666      0.753      0.664
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/29      30.1G     0.7438     0.7256     0.9831        175        608: 100% 36/36 [00:09<00:00,  3.88it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:01<00:00,  3.21it/s]
#                    all        150       2589       0.83      0.693      0.771      0.683
# Closing dataloader mosaic
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/29      30.1G     0.6118     0.6454          1         43        608: 100% 36/36 [00:07<00:00,  4.87it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:01<00:00,  3.19it/s]
#                    all        150       2589      0.856      0.677      0.773      0.687
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/29      30.1G     0.6015     0.6118     0.9773         54        608: 100% 36/36 [00:07<00:00,  4.82it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:01<00:00,  3.19it/s]
#                    all        150       2589      0.849      0.594      0.716      0.631
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/29      30.1G      0.609      0.607     0.9855         44        608: 100% 36/36 [00:07<00:00,  4.92it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:01<00:00,  3.08it/s]
#                    all        150       2589      0.864      0.667      0.776      0.682
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/29      30.1G     0.5915     0.5926     0.9771         52        608: 100% 36/36 [00:07<00:00,  4.92it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:01<00:00,  3.18it/s]
#                    all        150       2589      0.823      0.675      0.758      0.675
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/29      30.1G     0.5892     0.5844     0.9645         62        608: 100% 36/36 [00:07<00:00,  4.94it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:01<00:00,  3.15it/s]
#                    all        150       2589      0.885      0.679      0.782      0.701
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/29      30.1G     0.5755     0.5641     0.9564         47        608: 100% 36/36 [00:07<00:00,  4.91it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:01<00:00,  3.06it/s]
#                    all        150       2589      0.839      0.701      0.789      0.709
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/29      30.1G     0.5739      0.553     0.9653         40        608: 100% 36/36 [00:07<00:00,  5.04it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:01<00:00,  3.17it/s]
#                    all        150       2589      0.867       0.67      0.774      0.695
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/29      30.1G     0.5643     0.5479     0.9648         45        608: 100% 36/36 [00:07<00:00,  4.75it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:01<00:00,  3.16it/s]
#                    all        150       2589      0.902      0.692      0.801      0.723
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/29      30.1G      0.549     0.5167     0.9439         48        608: 100% 36/36 [00:07<00:00,  4.93it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:01<00:00,  3.17it/s]
#                    all        150       2589      0.879      0.685      0.788      0.709
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/29      30.1G     0.5383     0.5041     0.9441         45        608: 100% 36/36 [00:07<00:00,  4.86it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:01<00:00,  3.22it/s]
#                    all        150       2589      0.861      0.727      0.806      0.729
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/29      30.1G     0.5287     0.4773     0.9335         52        608: 100% 36/36 [00:07<00:00,  4.84it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:01<00:00,  3.19it/s]
#                    all        150       2589        0.9      0.705      0.808      0.727
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       26/29      30.1G     0.5204     0.4653      0.927         49        608: 100% 36/36 [00:07<00:00,  4.94it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:01<00:00,  3.23it/s]
#                    all        150       2589      0.922       0.68      0.812      0.735
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       27/29      30.1G     0.5182      0.471     0.9361         42        608: 100% 36/36 [00:07<00:00,  4.89it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:01<00:00,  3.22it/s]
#                    all        150       2589      0.876      0.713      0.821      0.743
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       28/29      30.1G     0.5014     0.4521     0.9261         57        608: 100% 36/36 [00:07<00:00,  4.76it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:01<00:00,  3.26it/s]
#                    all        150       2589       0.86      0.738      0.825      0.754
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       29/29      30.1G     0.5037     0.4429      0.924         55        608: 100% 36/36 [00:07<00:00,  5.00it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:01<00:00,  3.14it/s]
#                    all        150       2589      0.879      0.728      0.826      0.749
#
# 30 epochs completed in 0.103 hours.
# Optimizer stripped from runs/train/exp/weights/last.pt, saved as runs/train/exp/weights/last_striped.pt, 51.5MB
# Optimizer stripped from runs/train/exp/weights/best.pt, saved as runs/train/exp/weights/best_striped.pt, 51.5MB
#
# Validating runs/train/exp/weights/best.pt...
# Fusing layers...
# gelan-c summary: 467 layers, 25417128 parameters, 0 gradients, 102.5 GFLOPs
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:13<00:00,  2.78s/it]
#                    all        150       2589      0.859      0.738      0.824      0.754
#               biowaste        150        169      0.901      0.753      0.857      0.773
#              cardboard        150        391      0.866      0.744      0.819      0.731
#      combustible waste        150         25      0.823       0.68      0.837      0.791
#                  glass        150        594      0.923      0.791      0.883      0.803
#                  metal        150         29      0.851       0.69      0.778      0.723
#                  paper        150        679      0.862      0.754      0.822      0.745
#                plastic        150        678      0.891      0.785      0.856      0.782
#                  trash        150         24      0.755      0.708      0.743      0.686
# Results saved to runs/train/exp

# %%
# !ls {HOME}/yolov9/runs/train/exp/
# Out:
# confusion_matrix.png				    PR_curve.png	   val_batch0_pred.jpg
# events.out.tfevents.1719888895.903cec1f3172.2818.0  R_curve.png		   val_batch1_labels.jpg
# F1_curve.png					    results.csv		   val_batch1_pred.jpg
# hyp.yaml					    results.png		   val_batch2_labels.jpg
# labels_correlogram.jpg				    train_batch0.jpg	   val_batch2_pred.jpg
# labels.jpg					    train_batch1.jpg	   weights
# opt.yaml					    train_batch2.jpg
# P_curve.png					    val_batch0_labels.jpg

# %%
from IPython.display import Image

Image(filename=f"{HOME}/yolov9/runs/train/exp/results.png", width=1000)

# %%
from IPython.display import Image

Image(filename=f"{HOME}/yolov9/runs/train/exp/confusion_matrix.png", width=1000)

# %%
from IPython.display import Image

Image(filename=f"{HOME}/yolov9/runs/train/exp/val_batch0_pred.jpg", width=1000)

# %%
# %cd {HOME}/yolov9

# !python val.py \
--img 640 --batch 32 --conf 0.001 --iou 0.7 --device 0 \
--data {dataset.location}/data.yaml \
--weights {HOME}/yolov9/runs/train/exp/weights/best.pt
# Out:
# /content/yolov9
# val: data=/content/yolov9/Synthetic-trashes-2/data.yaml, weights=['/content/yolov9/runs/train/exp/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.7, max_det=300, task=val, device=0, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False, min_items=0
# YOLOv5 🚀 1e33dbb Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# gelan-c summary: 467 layers, 25417128 parameters, 0 gradients, 102.5 GFLOPs
# val: Scanning /content/yolov9/Synthetic-trashes-2/valid/labels.cache... 150 images, 0 backgrounds, 0 corrupt: 100% 150/150 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:19<00:00,  3.84s/it]
#                    all        150       2589      0.876      0.738      0.819      0.752
#               biowaste        150        169      0.962      0.743       0.85      0.764
#              cardboard        150        391      0.872      0.731      0.816      0.729
#      combustible waste        150         25      0.819      0.723      0.834      0.784
#                  glass        150        594      0.925      0.787      0.887      0.809
#                  metal        150         29      0.849      0.724      0.755      0.712
#                  paper        150        679      0.914       0.72      0.831      0.748
#                plastic        150        678      0.929      0.768      0.857      0.788
#                  trash        150         24      0.743      0.708       0.72      0.681
# Speed: 0.4ms pre-process, 36.8ms inference, 18.5ms NMS per image at shape (32, 3, 640, 640)
# Results saved to runs/val/exp

# %%
# !python detect.py \
--img 1280 --conf 0.1 --device 0 \
--weights {HOME}/yolov9/runs/train/exp/weights/best.pt \
--source {dataset.location}/test/images
# Out:
# detect: weights=['/content/yolov9/runs/train/exp/weights/best.pt'], source=/content/yolov9/Synthetic-trashes-2/test/images, data=data/coco128.yaml, imgsz=[1280, 1280], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=0, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 1e33dbb Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# gelan-c summary: 467 layers, 25417128 parameters, 0 gradients, 102.5 GFLOPs
# image 1/90 /content/yolov9/Synthetic-trashes-2/test/images/122-jpeg_jpg.rf.e7aba142179c0242deef6ac8002dbbf1.jpg: 1280x1280 1 biowaste, 2 cardboards, 2 glasss, 1 metal, 6 papers, 5 plastics, 135.7ms
# image 2/90 /content/yolov9/Synthetic-trashes-2/test/images/136-jpeg_jpg.rf.a17e93aa9114011cbcdda74607c323d3.jpg: 1280x1280 3 cardboards, 3 glasss, 4 papers, 7 plastics, 108.1ms
# image 3/90 /content/yolov9/Synthetic-trashes-2/test/images/140-jpeg_jpg.rf.e13d9a0691c0b4066324c0653ce74b64.jpg: 1280x1280 5 cardboards, 5 glasss, 2 papers, 3 plastics, 108.3ms
# image 4/90 /content/yolov9/Synthetic-trashes-2/test/images/156-jpeg_jpg.rf.7cc1edeecd3a2973a83f36fe399e022d.jpg: 1280x1280 4 cardboards, 7 glasss, 4 papers, 4 plastics, 1 trash, 108.6ms
# image 5/90 /content/yolov9/Synthetic-trashes-2/test/images/157-jpeg_jpg.rf.974e2d17a9d7e5ae8d364bd53ab365be.jpg: 1280x1280 2 biowastes, 5 cardboards, 5 glasss, 4 papers, 6 plastics, 1 trash, 108.4ms
# image 6/90 /content/yolov9/Synthetic-trashes-2/test/images/164-jpeg_jpg.rf.9185d06363d5da6ad6767c613bbe18cf.jpg: 1280x1280 2 biowastes, 3 cardboards, 2 glasss, 3 papers, 7 plastics, 108.2ms
# image 7/90 /content/yolov9/Synthetic-trashes-2/test/images/173-jpeg_jpg.rf.6046003cb337c532ad3dc020619536f4.jpg: 1280x1280 1 biowaste, 1 cardboard, 7 glasss, 3 papers, 5 plastics, 108.5ms
# image 8/90 /content/yolov9/Synthetic-trashes-2/test/images/195-jpeg_jpg.rf.c91a7bfc7a59d2763f96ef496e345ccf.jpg: 1280x1280 6 cardboards, 2 combustible wastes, 3 glasss, 6 papers, 5 plastics, 108.4ms
# image 9/90 /content/yolov9/Synthetic-trashes-2/test/images/2-jpeg_jpg.rf.edb4d01859401d69452dc15084deecba.jpg: 1280x1280 2 biowastes, 4 cardboards, 4 glasss, 8 papers, 4 plastics, 108.9ms
# image 10/90 /content/yolov9/Synthetic-trashes-2/test/images/200-jpeg_jpg.rf.691f2413183bbd0d061e31614924a4f0.jpg: 1280x1280 2 cardboards, 1 combustible waste, 4 glasss, 3 papers, 6 plastics, 108.7ms
# image 11/90 /content/yolov9/Synthetic-trashes-2/test/images/227-jpeg_jpg.rf.c95e3ec51ec70cab29fd49cdcf53c05b.jpg: 1280x1280 3 cardboards, 1 combustible waste, 6 glasss, 7 papers, 2 plastics, 110.4ms
# image 12/90 /content/yolov9/Synthetic-trashes-2/test/images/230-jpeg_jpg.rf.f59e42d0893f8f375e9afda596707c02.jpg: 1280x1280 4 cardboards, 2 glasss, 5 papers, 8 plastics, 107.9ms
# image 13/90 /content/yolov9/Synthetic-trashes-2/test/images/235-jpeg_jpg.rf.260af8d3242ae6915bc48293155f4389.jpg: 1280x1280 7 cardboards, 4 glasss, 5 papers, 6 plastics, 3 trashs, 108.8ms
# image 14/90 /content/yolov9/Synthetic-trashes-2/test/images/238-jpeg_jpg.rf.8e76dc67e3bdcf920bdae3538ac9c387.jpg: 1280x1280 3 cardboards, 5 glasss, 1 paper, 5 plastics, 110.3ms
# image 15/90 /content/yolov9/Synthetic-trashes-2/test/images/256-jpeg_jpg.rf.b7190d724b4b3975ad00d40fc76bef46.jpg: 1280x1280 4 cardboards, 4 glasss, 5 papers, 5 plastics, 109.2ms
# image 16/90 /content/yolov9/Synthetic-trashes-2/test/images/269-jpeg_jpg.rf.5177a0b7deba3ea1a65aa2c9c75fa075.jpg: 1280x1280 2 biowastes, 4 cardboards, 1 glass, 3 papers, 7 plastics, 109.2ms
# image 17/90 /content/yolov9/Synthetic-trashes-2/test/images/273-jpeg_jpg.rf.bef7e925c465590592444afcb136dbf2.jpg: 1280x1280 5 cardboards, 6 glasss, 9 papers, 10 plastics, 100.0ms
# image 18/90 /content/yolov9/Synthetic-trashes-2/test/images/284-jpeg_jpg.rf.2211b3c64951c60cd365ac19bbd33f19.jpg: 1280x1280 3 cardboards, 8 glasss, 5 papers, 4 plastics, 1 trash, 109.8ms
# image 19/90 /content/yolov9/Synthetic-trashes-2/test/images/294-jpeg_jpg.rf.f3b3118715c12df239f980f52575a8a2.jpg: 1280x1280 3 biowastes, 4 cardboards, 12 glasss, 9 papers, 6 plastics, 1 trash, 109.0ms
# image 20/90 /content/yolov9/Synthetic-trashes-2/test/images/30-jpeg_jpg.rf.a13159eab6a6cb2a8a23df3bd2aeae35.jpg: 1280x1280 3 cardboards, 1 combustible waste, 6 glasss, 5 papers, 5 plastics, 1 trash, 108.4ms
# image 21/90 /content/yolov9/Synthetic-trashes-2/test/images/301-jpeg_jpg.rf.07fa6dec76ba8154ad52e9b27604244f.jpg: 1280x1280 5 cardboards, 4 glasss, 6 papers, 9 plastics, 108.1ms
# image 22/90 /content/yolov9/Synthetic-trashes-2/test/images/304-jpeg_jpg.rf.a95c2d6eb49ba83ceaf1c7ddeaab9b7a.jpg: 1280x1280 2 biowastes, 5 cardboards, 1 combustible waste, 3 glasss, 7 papers, 7 plastics, 107.0ms
# image 23/90 /content/yolov9/Synthetic-trashes-2/test/images/321-jpeg_jpg.rf.8c9723061e6e5fb9f55f630367b5a202.jpg: 1280x1280 2 cardboards, 3 glasss, 2 metals, 7 papers, 6 plastics, 110.2ms
# image 24/90 /content/yolov9/Synthetic-trashes-2/test/images/323-jpeg_jpg.rf.3f0560688fbd180022c34c8174e4439d.jpg: 1280x1280 4 cardboards, 2 combustible wastes, 4 glasss, 4 papers, 10 plastics, 109.0ms
# image 25/90 /content/yolov9/Synthetic-trashes-2/test/images/340-jpeg_jpg.rf.8ff48e63fc2c3bc3af51e404d2a2e380.jpg: 1280x1280 5 cardboards, 7 glasss, 7 papers, 4 plastics, 110.0ms
# image 26/90 /content/yolov9/Synthetic-trashes-2/test/images/359-jpeg_jpg.rf.1ef15fd580909ce9807ef88ad5f60fd6.jpg: 1280x1280 4 cardboards, 2 glasss, 10 papers, 5 plastics, 108.6ms
# image 27/90 /content/yolov9/Synthetic-trashes-2/test/images/375-jpeg_jpg.rf.8a4142d4395a573ca8468455a0f4f76b.jpg: 1280x1280 4 biowastes, 2 cardboards, 2 combustible wastes, 4 glasss, 9 papers, 4 plastics, 108.6ms
# image 28/90 /content/yolov9/Synthetic-trashes-2/test/images/383-jpeg_jpg.rf.78c1969546b05bbf2cd70046fab274d1.jpg: 1280x1280 1 biowaste, 3 glasss, 10 papers, 6 plastics, 1 trash, 108.7ms
# image 29/90 /content/yolov9/Synthetic-trashes-2/test/images/389-jpeg_jpg.rf.aba6201a20b967c47553c70cdfd3e899.jpg: 1280x1280 1 biowaste, 5 cardboards, 5 glasss, 7 papers, 4 plastics, 109.7ms
# image 30/90 /content/yolov9/Synthetic-trashes-2/test/images/396-jpeg_jpg.rf.017546225fa08f6db66f0a653ad924b0.jpg: 1280x1280 3 cardboards, 5 glasss, 3 papers, 8 plastics, 108.5ms
# image 31/90 /content/yolov9/Synthetic-trashes-2/test/images/406-jpeg_jpg.rf.6ddf28de4207b1fba247f74ec099c11d.jpg: 1280x1280 5 cardboards, 10 glasss, 2 papers, 6 plastics, 108.8ms
# image 32/90 /content/yolov9/Synthetic-trashes-2/test/images/409-jpeg_jpg.rf.c509041966de5c31035045900e3059bc.jpg: 1280x1280 1 biowaste, 6 cardboards, 6 glasss, 8 papers, 4 plastics, 1 trash, 108.8ms
# image 33/90 /content/yolov9/Synthetic-trashes-2/test/images/415-jpeg_jpg.rf.b328ab60110316cde3ae04454094bd45.jpg: 1280x1280 2 biowastes, 4 cardboards, 4 glasss, 2 metals, 1 paper, 5 plastics, 110.4ms
# image 34/90 /content/yolov9/Synthetic-trashes-2/test/images/431-jpeg_jpg.rf.c549ce350243941a19f2cadeded2f9ef.jpg: 1280x1280 2 biowastes, 2 cardboards, 2 combustible wastes, 4 glasss, 1 metal, 5 papers, 4 plastics, 110.2ms
# image 35/90 /content/yolov9/Synthetic-trashes-2/test/images/435-jpeg_jpg.rf.cead1c1fa91b2fcd75401722ff587fc3.jpg: 1280x1280 1 biowaste, 2 cardboards, 9 glasss, 10 papers, 5 plastics, 109.9ms
# image 36/90 /content/yolov9/Synthetic-trashes-2/test/images/44-jpeg_jpg.rf.5f46ce8fcccedb72befc1575c3715ecc.jpg: 1280x1280 1 biowaste, 2 cardboards, 6 glasss, 10 papers, 2 plastics, 110.1ms
# image 37/90 /content/yolov9/Synthetic-trashes-2/test/images/466-jpeg_jpg.rf.39a4a60c834efcbf2961e54769941451.jpg: 1280x1280 1 biowaste, 2 cardboards, 3 combustible wastes, 4 glasss, 3 papers, 4 plastics, 1 trash, 110.0ms
# image 38/90 /content/yolov9/Synthetic-trashes-2/test/images/495-jpeg_jpg.rf.7219a50576defc9ed72b0c73b580d3df.jpg: 1280x1280 4 cardboards, 1 combustible waste, 1 glass, 5 papers, 7 plastics, 107.3ms
# image 39/90 /content/yolov9/Synthetic-trashes-2/test/images/507-jpeg_jpg.rf.08b199cfe3c48b281cb5ade675e92d03.jpg: 1280x1280 1 biowaste, 5 cardboards, 5 glasss, 5 papers, 4 plastics, 109.0ms
# image 40/90 /content/yolov9/Synthetic-trashes-2/test/images/509-jpeg_jpg.rf.cab3fe9dc48b7f338791f3b1959c611a.jpg: 1280x1280 4 biowastes, 4 cardboards, 4 glasss, 1 metal, 3 papers, 2 plastics, 109.6ms
# image 41/90 /content/yolov9/Synthetic-trashes-2/test/images/536-jpeg_jpg.rf.95240a2231adf5b46fbb36e21bf5f6ef.jpg: 1280x1280 5 biowastes, 3 cardboards, 5 glasss, 7 papers, 5 plastics, 111.6ms
# image 42/90 /content/yolov9/Synthetic-trashes-2/test/images/540-jpeg_jpg.rf.583f1708d071a95ba43a5d208bd4230c.jpg: 1280x1280 2 biowastes, 2 combustible wastes, 2 glasss, 4 papers, 4 plastics, 110.9ms
# image 43/90 /content/yolov9/Synthetic-trashes-2/test/images/543-jpeg_jpg.rf.47c2d08ef3ef345f42c77fda55c4a665.jpg: 1280x1280 5 cardboards, 2 glasss, 3 papers, 4 plastics, 110.1ms
# image 44/90 /content/yolov9/Synthetic-trashes-2/test/images/56-jpeg_jpg.rf.844545bb438859d26b6a278e03ce111e.jpg: 1280x1280 1 cardboard, 1 combustible waste, 8 glasss, 4 papers, 4 plastics, 111.4ms
# image 45/90 /content/yolov9/Synthetic-trashes-2/test/images/564-jpeg_jpg.rf.b2f232729161ce0ae966d227feb3270c.jpg: 1280x1280 5 cardboards, 5 glasss, 10 papers, 2 plastics, 110.5ms
# image 46/90 /content/yolov9/Synthetic-trashes-2/test/images/565-jpeg_jpg.rf.1e1099eff4ad3842ab1003cfdaa02da0.jpg: 1280x1280 5 cardboards, 2 glasss, 5 papers, 2 plastics, 110.0ms
# image 47/90 /content/yolov9/Synthetic-trashes-2/test/images/575-jpeg_jpg.rf.3fdeaa5ee46d21faac48dc5daf389849.jpg: 1280x1280 2 biowastes, 1 cardboard, 2 glasss, 7 papers, 7 plastics, 110.0ms
# image 48/90 /content/yolov9/Synthetic-trashes-2/test/images/584-jpeg_jpg.rf.5e8bc6e46c94578520c61a2a80421a4e.jpg: 1280x1280 3 cardboards, 1 combustible waste, 7 glasss, 1 metal, 4 papers, 4 plastics, 2 trashs, 109.5ms
# image 49/90 /content/yolov9/Synthetic-trashes-2/test/images/589-jpeg_jpg.rf.ac78dc47e72301732dba4b71e9050232.jpg: 1280x1280 2 biowastes, 3 cardboards, 2 combustible wastes, 6 glasss, 9 papers, 3 plastics, 109.2ms
# image 50/90 /content/yolov9/Synthetic-trashes-2/test/images/592-jpeg_jpg.rf.a53a150b3d9ad475815076dcbf0d6b11.jpg: 1280x1280 3 cardboards, 6 glasss, 2 papers, 7 plastics, 112.3ms
# image 51/90 /content/yolov9/Synthetic-trashes-2/test/images/597-jpeg_jpg.rf.52ab23464fcf65f4fd0505672f581a23.jpg: 1280x1280 5 cardboards, 1 combustible waste, 4 glasss, 3 papers, 7 plastics, 111.4ms
# image 52/90 /content/yolov9/Synthetic-trashes-2/test/images/599-jpeg_jpg.rf.4469737970c0b56413c24a6fdf0bdbcd.jpg: 1280x1280 2 biowastes, 5 cardboards, 6 glasss, 6 papers, 3 plastics, 109.8ms
# image 53/90 /content/yolov9/Synthetic-trashes-2/test/images/606-jpeg_jpg.rf.77a93b6571dca6222b26568c1133edb8.jpg: 1280x1280 4 cardboards, 4 glasss, 7 papers, 7 plastics, 108.3ms
# image 54/90 /content/yolov9/Synthetic-trashes-2/test/images/611-jpeg_jpg.rf.c8f59e4f7c4009ff9b62d7603096986b.jpg: 1280x1280 9 cardboards, 6 glasss, 4 papers, 4 plastics, 109.9ms
# image 55/90 /content/yolov9/Synthetic-trashes-2/test/images/617-jpeg_jpg.rf.a1781070e52d5d2cd6b5471fc45916e8.jpg: 1280x1280 1 biowaste, 5 cardboards, 1 combustible waste, 5 glasss, 9 papers, 5 plastics, 109.1ms
# image 56/90 /content/yolov9/Synthetic-trashes-2/test/images/62-jpeg_jpg.rf.c67775547cef02a4cf71f6e656dd9e94.jpg: 1280x1280 1 biowaste, 4 cardboards, 1 combustible waste, 7 glasss, 6 papers, 5 plastics, 110.9ms
# image 57/90 /content/yolov9/Synthetic-trashes-2/test/images/621-jpeg_jpg.rf.bf8b3f63320cc0d7ff7b540cf8b062fe.jpg: 1280x1280 4 cardboards, 6 glasss, 7 papers, 5 plastics, 109.6ms
# image 58/90 /content/yolov9/Synthetic-trashes-2/test/images/623-jpeg_jpg.rf.39ea025d7668b3deaaed5d36366ad954.jpg: 1280x1280 1 biowaste, 8 cardboards, 5 glasss, 2 papers, 5 plastics, 110.8ms
# image 59/90 /content/yolov9/Synthetic-trashes-2/test/images/637-jpeg_jpg.rf.ec1c7a6968663bd1c3d37ea2b562ecb8.jpg: 1280x1280 2 biowastes, 3 cardboards, 4 glasss, 4 papers, 2 plastics, 1 trash, 108.5ms
# image 60/90 /content/yolov9/Synthetic-trashes-2/test/images/670-jpeg_jpg.rf.20262150767f6a029b8a99d1f37cbb23.jpg: 1280x1280 2 biowastes, 2 cardboards, 4 glasss, 5 papers, 7 plastics, 111.4ms
# image 61/90 /content/yolov9/Synthetic-trashes-2/test/images/673-jpeg_jpg.rf.988daa5175c46f8bac0ca3330e1d613c.jpg: 1280x1280 3 cardboards, 8 glasss, 5 papers, 6 plastics, 109.3ms
# image 62/90 /content/yolov9/Synthetic-trashes-2/test/images/677-jpeg_jpg.rf.89c7a46cd3bd99b183b3d4ab031f0633.jpg: 1280x1280 2 biowastes, 5 cardboards, 8 glasss, 8 papers, 5 plastics, 110.1ms
# image 63/90 /content/yolov9/Synthetic-trashes-2/test/images/680-jpeg_jpg.rf.a7c2b4c53bd7023298c0d9e4080c9a78.jpg: 1280x1280 3 cardboards, 9 glasss, 4 papers, 3 plastics, 1 trash, 108.0ms
# image 64/90 /content/yolov9/Synthetic-trashes-2/test/images/682-jpeg_jpg.rf.44ce9484f0d45da5d7616ff0ea142119.jpg: 1280x1280 1 biowaste, 3 cardboards, 1 combustible waste, 4 glasss, 1 metal, 3 papers, 8 plastics, 111.0ms
# image 65/90 /content/yolov9/Synthetic-trashes-2/test/images/683-jpeg_jpg.rf.af643a3a94a8d1fc5a43563ded1550e7.jpg: 1280x1280 3 biowastes, 6 cardboards, 7 glasss, 9 papers, 9 plastics, 110.3ms
# image 66/90 /content/yolov9/Synthetic-trashes-2/test/images/696-jpeg_jpg.rf.5b546b5ac8028f6b44a2b36635e3c9dd.jpg: 1280x1280 9 glasss, 5 papers, 4 plastics, 1 trash, 110.4ms
# image 67/90 /content/yolov9/Synthetic-trashes-2/test/images/697-jpeg_jpg.rf.6d717fa35ae1e0a6801dec7f4b168e6a.jpg: 1280x1280 1 biowaste, 8 cardboards, 1 combustible waste, 7 glasss, 4 papers, 4 plastics, 110.8ms
# image 68/90 /content/yolov9/Synthetic-trashes-2/test/images/698-jpeg_jpg.rf.d080309ffc25a79b62a1c669b7345898.jpg: 1280x1280 5 cardboards, 5 glasss, 2 metals, 5 papers, 6 plastics, 110.5ms
# image 69/90 /content/yolov9/Synthetic-trashes-2/test/images/705-jpeg_jpg.rf.19e35164657cbaac6e34fc5c25a6a374.jpg: 1280x1280 3 glasss, 6 papers, 4 plastics, 110.3ms
# image 70/90 /content/yolov9/Synthetic-trashes-2/test/images/730-jpeg_jpg.rf.e181427c572746ae50419dc287e0d30d.jpg: 1280x1280 1 biowaste, 2 cardboards, 1 combustible waste, 5 glasss, 5 papers, 7 plastics, 1 trash, 111.9ms
# image 71/90 /content/yolov9/Synthetic-trashes-2/test/images/739-jpeg_jpg.rf.a0e7b4ef77b656df605b9e59344871ab.jpg: 1280x1280 1 biowaste, 3 cardboards, 4 glasss, 6 papers, 4 plastics, 110.3ms
# image 72/90 /content/yolov9/Synthetic-trashes-2/test/images/744-jpeg_jpg.rf.376407d2f384368b449b8bdbbc7f7edd.jpg: 1280x1280 1 biowaste, 2 cardboards, 8 glasss, 2 metals, 11 papers, 3 plastics, 110.7ms
# image 73/90 /content/yolov9/Synthetic-trashes-2/test/images/745-jpeg_jpg.rf.bc3b4224afd3f044d17d25df028d39e4.jpg: 1280x1280 2 biowastes, 3 cardboards, 5 glasss, 3 papers, 6 plastics, 1 trash, 110.2ms
# image 74/90 /content/yolov9/Synthetic-trashes-2/test/images/75-jpeg_jpg.rf.0212ee2d997d332b9d73e4f7e9c83ba0.jpg: 1280x1280 2 biowastes, 6 cardboards, 1 combustible waste, 5 glasss, 1 metal, 4 papers, 5 plastics, 110.2ms
# image 75/90 /content/yolov9/Synthetic-trashes-2/test/images/750-jpeg_jpg.rf.a5637a748eb32b42428ab52b8e29d76f.jpg: 1280x1280 2 biowastes, 7 cardboards, 8 glasss, 1 metal, 4 papers, 5 plastics, 1 trash, 110.7ms
# image 76/90 /content/yolov9/Synthetic-trashes-2/test/images/758-jpeg_jpg.rf.00e4d9fcd3101449f4ac4194f258e4be.jpg: 1280x1280 4 cardboards, 1 combustible waste, 3 glasss, 10 papers, 6 plastics, 110.3ms
# image 77/90 /content/yolov9/Synthetic-trashes-2/test/images/768-jpeg_jpg.rf.6d4c18146348ff4cfad0dd89aa3f7da4.jpg: 1280x1280 1 biowaste, 1 cardboard, 2 combustible wastes, 3 glasss, 2 metals, 4 papers, 7 plastics, 109.5ms
# image 78/90 /content/yolov9/Synthetic-trashes-2/test/images/775-jpeg_jpg.rf.88888400ee58c7084cb59d3df5e786ce.jpg: 1280x1280 3 cardboards, 4 glasss, 1 paper, 6 plastics, 110.4ms
# image 79/90 /content/yolov9/Synthetic-trashes-2/test/images/79-jpeg_jpg.rf.4b24f77321f6b114a931d705bd5ebdbe.jpg: 1280x1280 1 biowaste, 2 cardboards, 9 glasss, 5 papers, 4 plastics, 1 trash, 111.4ms
# image 80/90 /content/yolov9/Synthetic-trashes-2/test/images/89-jpeg_jpg.rf.e4119173dd048dc3e1b083010db0b5e7.jpg: 1280x1280 1 biowaste, 4 cardboards, 3 glasss, 1 metal, 10 papers, 5 plastics, 110.2ms
# image 81/90 /content/yolov9/Synthetic-trashes-2/test/images/90-jpeg_jpg.rf.92f6b2297dcc787439a8c2ac542547b3.jpg: 1280x1280 1 biowaste, 1 cardboard, 7 glasss, 1 metal, 3 papers, 9 plastics, 1 trash, 111.6ms
# image 82/90 /content/yolov9/Synthetic-trashes-2/test/images/96-jpeg_jpg.rf.3dcd87d1c33d77edbebcca44881d4046.jpg: 1280x1280 5 cardboards, 9 glasss, 7 papers, 3 plastics, 1 trash, 109.1ms
# image 83/90 /content/yolov9/Synthetic-trashes-2/test/images/97-jpeg_jpg.rf.ce566143666c6f51f86289b640d133cf.jpg: 1280x1280 2 biowastes, 2 cardboards, 6 glasss, 4 papers, 4 plastics, 111.0ms
# image 84/90 /content/yolov9/Synthetic-trashes-2/test/images/IMG_4240_jpg.rf.b0cf3a48a2d595f9c928cf355fbc2224.jpg: 1280x1280 11 biowastes, 7 cardboards, 8 glasss, 1 metal, 8 papers, 13 plastics, 112.2ms
# image 85/90 /content/yolov9/Synthetic-trashes-2/test/images/IMG_4241_jpg.rf.3093e8e104f8a1c387928e7963b68e4a.jpg: 1280x1280 1 cardboard, 1 combustible waste, 4 papers, 2 plastics, 111.4ms
# image 86/90 /content/yolov9/Synthetic-trashes-2/test/images/frame0_11-16-1904_jpg.rf.524ef3bbad2e5f1f82d5ddcddc4bf665.jpg: 1280x1280 2 biowastes, 7 cardboards, 4 glasss, 1 metal, 15 papers, 5 plastics, 110.8ms
# image 87/90 /content/yolov9/Synthetic-trashes-2/test/images/frame4_11-17_1751_Front_jpg.rf.4473ca91063c087a53e0ec734e5bf9f4.jpg: 1280x1280 3 cardboards, 6 glasss, 2 metals, 9 papers, 8 plastics, 110.3ms
# image 88/90 /content/yolov9/Synthetic-trashes-2/test/images/frame4_11-17_1951_Front_jpg.rf.64aaa3c9e4770f6703a20d66b4e5d420.jpg: 1280x1280 2 cardboards, 1 glass, 2 papers, 3 plastics, 109.3ms
# image 89/90 /content/yolov9/Synthetic-trashes-2/test/images/frame8_11-16_1819_Front_jpg.rf.58cc5d23896076782d0795218c14c82d.jpg: 1280x1280 5 cardboards, 2 glasss, 1 paper, 3 plastics, 111.4ms
# image 90/90 /content/yolov9/Synthetic-trashes-2/test/images/frame8_11-16_1849_jpg.rf.53f92c60ea0e635da7f27f40b3fbb041.jpg: 1280x1280 2 biowastes, 1 cardboard, 1 combustible waste, 4 glasss, 10 papers, 8 plastics, 1 trash, 111.7ms
# Speed: 2.0ms pre-process, 110.0ms inference, 8.4ms NMS per image at shape (1, 3, 1280, 1280)
# Results saved to runs/detect/exp3

# %%
import glob

from IPython.display import Image, display

for image_path in glob.glob(f'{HOME}/yolov9/runs/detect/exp3/*.jpg')[:2]:
      display(Image(filename=image_path, width=600))
